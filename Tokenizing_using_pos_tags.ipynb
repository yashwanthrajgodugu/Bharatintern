# %% [markdown]
# <a href="https://colab.research.google.com/github/yashwanthrajgodugu/Bharatintern/blob/main/Tokenizing_using_pos_tags.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
sentence = "Ram sing a song beautifully."

# %%
tokens = nltk.word_tokenize(sentence)

# %%
pos_tags = nltk.pos_tag(tokens)

# %%
verbs = [word for word, pos in pos_tags if pos.startswith('VB')]
nouns = [word for word, pos in pos_tags if pos.startswith('NN')]
print("Verbs:", verbs)
print("Nouns:", nouns)
# Out:
# Verbs: ['sing']
# Nouns: ['Ram', 'song']
